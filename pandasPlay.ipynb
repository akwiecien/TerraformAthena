# %%
import pandas

# %%
df = pandas.read_csv('flights.csv')

# %%
df.head(60)
# Out:
#           date  airlines  flight_number origin destination  departure  \
# 0   2014-04-01     19805              1    JFK         LAX        854
# 1   2014-04-01     19805              2    LAX         JFK        944
# 2   2014-04-01     19805              3    JFK         LAX       1224
# 3   2014-04-01     19805              4    LAX         JFK       1240
# 4   2014-04-01     19805              5    DFW         HNL       1300
# 5   2014-04-01     19805              6    OGG         DFW       1901
# 6   2014-04-01     19805              7    DFW         OGG       1410
# 7   2014-04-01     19805              8    HNL         DFW       1659
# 8   2014-04-01     19805              9    JFK         LAX        648
# 9   2014-04-01     19805             10    LAX         JFK       2156
# 10  2014-04-01     19805             12    LAX         JFK       1113
# 11  2014-04-01     19805             14    OGG         LAX       2235
# ...
